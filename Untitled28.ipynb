# %%
a = 5

# %%
type(a)
# Out:
# int

# %%
a + 5
# Out:
# 10

# %%
a.__add__(5)
# Out:
# 10

# %%
string = 'hello word'

# %%
type(string)
# Out:
# str

# %%
string.capitalize()
# Out:
# 'Hello word'

# %%
string.lower()
# Out:
# 'hello word'

# %%
string.__add__('words')
# Out:
# 'hello wordwords'

# %%
string.center(100)
# Out:
# '                                             hello word                                             '

# %%
string.center(100,'*')
# Out:
# '*********************************************hello word*********************************************'

# %%
string.ljust(100)
# Out:
# 'hello word                                                                                          '

# %%
string.rjust(100)
# Out:
# '                                                                                          hello word'

# %%
a= 1234
a = input("enter the number")
if a == a:
  print("success")
else:
  print("sprry ")

# %%
string.index('o')
# Out:
# 4

# %%
string.find('o')
# Out:
# 4

# %%
string.rfind('o')
# Out:
# 7

# %%
string = ("hello word")

# %%
string = ('helloword\tword')

# %%
string = ('hello\nword')

# %%
string
# Out:
# 'hello\nword'

# %%
'     hello'.strip()
# Out:
# 'hello'

# %%
'rokn123'.isalnum()
# Out:
# True

# %%
'im {} surname {}'.format('roman','pateliya')
# Out:
# 'im roman surname pateliya'

# %%
f'im {name}'
