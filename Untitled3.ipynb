# %%
numbers = input("enter the number")
temp = ''
for n in num.split(','):
    if n not in temp:
        temp += n
else:
    temp = ','.join(temp)
numbers = temp
numbers.split(',')
for i in range(1,11):
    for num in numbers:
      m = f"{i}".zfill(2)
      n = int(num)
      r = f"{n*i}".zfill(2)
    
      print(f"{n} * {m} = {r}" , end = "\t|\t")
    else:
      print()
# Out:
# enter the number6,7,8,9

# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
t = 6,7,8

# %%
t.append(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-7bc26d8122b5> in <module>()
# ----> 1 t.append(5)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t  = []

# %%
type(t)
# Out:
# list

# %%
t = [7,8,9,9]

# %%
t.append(5)

# %%
t
# Out:
# [7, 8, 9, 9, 5]

# %%
t.extend([6,7,8])

# %%
t
# Out:
# [7, 8, 9, 9, 5, 6, 7, 8]

# %%
for
