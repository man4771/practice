# %%
preset_acc_number = 5667654000

def acc_details(preset_acc_number):
  acc_details = {
    'acc_holder' : str(),
    'pin' : int(),
    'balance' : float(),
    'transaction' : [],
}
  for i in acc_details.items():
    acc_details.setdefault(i)
  return acc_details


transaction_details = {
    'amount' : int(),
    'tr_type' : str(),
    'datetime' : object(),
}


bank = dict()

# %%
import random
def new_acc_number(acc_number,acc_details,bank):
  new_acc = preset_acc_number + len(bank) + 1
  acc_holder = input("enter the holder name")
  if acc_details == acc_details['acc_holder']:
    print(f"holder name is :{acc_details['acc_holder']}")
    pin = ranint(1000,9999)
  return new_acc,bank

# %%
def acc_details(acc_holder):
acc_details =  {
    acc_holder = str()
    pin = int()
    balance = float()
    
}
for k,v in acc_details.items():
  acc_details.setdefault(k,v)
return acc_details
# Out:
#   File "<ipython-input-49-6804b6207b23>", line 2
#     acc_details =  {
#               ^
# IndentationError: expected an indented block

# %%
new_acc_number(5667654000,acc_details,bank)
# Out:
# enter the holder namerooman
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-f4a40c704b89> in <module>()
# ----> 1 new_acc_number(5667654000,acc_details,bank)
#
# <ipython-input-44-ba8f44f16243> in new_acc_number(acc_number, acc_details, bank)
#       3   new_acc = preset_acc_number + len(bank) + 1
#       4   acc_holder = input("enter the holder name")
# ----> 5   if acc_details == acc_details['acc_holder']:
#       6     print(f"holder name is :{acc_details['acc_holder']}")
#       7     pin = ranint(1000,9999)
#
# TypeError: 'function' object is not subscriptable
