# %%
for  i in range(11,0,-1):
  print('' * (10-i) + '* ' * i)

  if direction == 'triangle':
    for i in range(1, rows+1):
      print(' ' * (rows-i) + f'{pr_char} ' * i)


      def print_pattern(rows, pr_char='*', direction='triangle'):
  # right
# Out:
# * * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * *
# * * * * * * * *
# * * * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(11,0,-1):
  print('* ' * i)

   # reverse right
# Out:
# * * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * *
# * * * * * * * *
# * * * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(1,11):
  print('* ' * i)


  def print_pattern(rows, pr_char='*', direction='triangle'):
    

  #right
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *
# * * * * * * * *
# * * * * * * * * *
# * * * * * * * * * *

# %%
def print_pattern(row,char='*',direction='triangle'):
  if direction == 'triangle':
    for i in range(1,rows+1):
      print('' * (row-i) + f'(char)' * row)

# %%
print_pattern(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8cb7a7c34f55> in <module>()
# ----> 1 print_pattern(10)
#
# <ipython-input-15-b480ad11b689> in print_pattern(row, char, direction)
#       1 def print_pattern(row,char='*',direction='triangle'):
#       2   if direction == 'triangle':
# ----> 3     for i in range(1,rows+1):
#       4       print('' * (row-i) + f'(char)' * row)
#       5
#
# NameError: name 'rows' is not defined
