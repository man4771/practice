# %%
bank_sc =          {
      567895665: {
  'pin' : 4771,
  'balance' : 100.00,
  'holder_name' : 'roman',
  'transaction' :[{
             'amount' : float(),
             'tr_type' : str(),
             'datetime' : str(),
                        }]
      },
      567895666: {},
      567895667: {},
}
present_acc_number = 10003456000

acc_information = {
    'pin' : int(),
    'balance' : float(),
    'holder_name' : str(),
    'transaction' : []

                    }

transaction_information = {
    'amount' : float(),
    'tr_type' : str(),
    'datatime' : object(),
                          }                
 
bank = dict()

# %%
acc_num = present_acc_number + len(bank) + 1
print(acc_num)
bank.setdefault(present_acc_number , acc_information)
# Out:
# 10003456001
# {'balance': 0.0, 'holder_name': '', 'pin': 0, 'transaction': []}

# %%
bank
# Out:
# {10003456000: {'balance': 0.0, 'holder_name': '', 'pin': 0, 'transaction': []}}

# %%
acc_num = present_acc_number + len(bank) + 1
print(acc_num)
bank.setdefault(present_acc_number , acc_information)
# Out:
# 10003456002
# {'balance': 0.0, 'holder_name': '', 'pin': 0, 'transaction': []}

# %%
import datetime

bank[10003456000]['balance'] += 5000.0
new_tr = {
    'amount' : 10000,
    'tr_type' : 'cr',
    'datetime' : datetime.datetime.now()

}
bank[10003456000]['transaction'].append(new_tr)

# %%
bank[10003456000]
# Out:
# {'balance': 15000.0,
#  'holder_name': '',
#  'pin': 0,
#  'transaction': [{'amount': 10000,
#    'datetime': datetime.datetime(2022, 7, 1, 9, 31, 34, 592494),
#    'tr_type': 'cr'}]}

# %%
bank[10003456000]['balance'] += 5000
new_tr = {
    'amount'  : 10000,
    'tr_type' : 'cr',
    'datetime' : datetime.datetime.now()
}
bank[10003456000]
# Out:
# {'balance': 30000.0,
#  'holder_name': '',
#  'pin': 0,
#  'transaction': [{'amount': 10000,
#    'datetime': datetime.datetime(2022, 7, 1, 9, 31, 34, 592494),
#    'tr_type': 'cr'}]}

# %%
bank[10003456000]['transaction']
# Out:
# [{'amount': 10000,
#   'datetime': datetime.datetime(2022, 7, 1, 9, 31, 34, 592494),
#   'tr_type': 'cr'}]

# %%
for t in bank[10003456000]['transaction']:
  for k,v in t.items():
    print(k,v)
# Out:
# amount 10000
# tr_type cr
# datetime 2022-07-01 09:31:34.592494

# %%
acc_num  = present_acc_number + len(bank) + 1
print(acc_num)
bank.setdefault(present_acc_number , acc_information)
# Out:
# 10003456002
# {'balance': 30000.0,
#  'holder_name': '',
#  'pin': 0,
#  'transaction': [{'amount': 10000,
#    'datetime': datetime.datetime(2022, 7, 1, 9, 31, 34, 592494),
#    'tr_type': 'cr'}]}

# %%
bank[acc_information]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-9f40edf2fa57> in <module>()
# ----> 1 bank[acc_information]
#
# TypeError: unhashable type: 'dict'

# %%
acc_information()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-649d9a90f1f4> in <module>()
# ----> 1 acc_information()
#
# TypeError: 'dict' object is not callable

# %%
acc_information
# Out:
# {'balance': 30000.0,
#  'holder_name': '',
#  'pin': 0,
#  'transaction': [{'amount': 10000,
#    'datetime': datetime.datetime(2022, 7, 1, 9, 31, 34, 592494),
#    'tr_type': 'cr'}]}

# %%
s =  "||"
for t in bank[10003456000]['transaction'][0].t():
  s += t.center(60 , '-') + "\t\t"
s = s.strip()
print("╔═══════════════","═══════════════════════","═══════════════════════",sep="╦",end="╗")
print()

for tr in bank[10003456002]['transaction']:
  print("||" , tr)
for k.v in t.items():
  if  k == datetime():
    print(f{v.strftime("%x","%X") ,end = '||'.ljust(14)})
  else:
    print()
# Out:
#   File "<ipython-input-52-c77b2283f6fa>", line 12
#     print(f{v.strftime("%x","%X") ,end = '||'.ljust(14)})
#            ^
# SyntaxError: invalid syntax

# %%
acc_number = 345678965000

acc_info = {
    345678965000, 
    {
    'pin' : int(),
    'acc_holder' : str(),
    'balance' : float(),
    'transaction' : []
    }
}

transaction_info = {
     'amount' : float(),
     'tr_type' : str(),
     'datetime' : object()
}
bank = dict()

def new_acc(acc_number):
  new_acc = acc_number + len(1) + 1
  print(new_acc)
  bank.setdefault(acc_number , transaction_info.copy())

def credit_info(acc_number):
  bank[acc_number]['balance'] += 3000
  new_tr = {
      'amount' : 5000,
      'tr_type' : 'cr',
      'datetime' : datetime.datetime.now()
  }
  bank[acc_number]['transaction'].append(new_tr)
def acc_information(acc_number):
      print("account information".center(60,"-"))
    for k,v in bank[acc_number].items():
      if k == 'transaction':
          print(f"Your total {k} is {len(v)}")
      else:
          print(f"Your account {k[4:]} is {v}")
    
def acc_services(acc_information,new_acc,credit_info):
        choice = input("enter the eny key")
        print("press 1 -> acc_information \n ")
        print("prees 2 -> new_acc \n")
        print("press 3 -> credit_info \n")
        choice.isnumeric()
        choice = int(choice)
        if choice == 1:
            acc_information(acc_number)
        new_acc = input("enter acc_holder name")
        if choice == 2:
              print("new_acc(acc_number)")
              if choice == 3:
                print("credit_info(acc_number)")
        else:
            print("invalid info")
# Out:
#   File "<ipython-input-3-7187d414dcfd>", line 35
#     for k,v in bank[acc_number].items():
#                                         ^
# IndentationError: unindent does not match any outer indentation level

# %%
preset_acc_number = 34567543000

def new_acc_number(preset_acc_number,bank):
  ac_num = preset_acc_number + len(bank) + 1
  return ac_num

bank = dict()

# %%
new_acc_number(34567543000,bank)
# Out:
# 34567543001
