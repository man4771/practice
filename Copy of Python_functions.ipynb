# %% [markdown]
# # Function in Python
#
# # What is function?
# > * ## A function is a block of organized, resusable code that is used to perform a single, related action.
# > * ## Functions provides better modularity for your application and a high degree of code reusing.
# > * ## A function is defined using def keyword.
#
# # Types of Functions:
# > * ## Built-in function - print(), help(), len(), type(), id() etc.
# > * ## User defined function - We can define ourselves to do certain specific task are referred as user-defined functions.
#
# # Types of function based on operations (output):
# > * ## Returning functions - using return keyword
# >> ## The return statement returns with a value from a function.
# > * ## Non-Returning functions
# >> ## 'Return' without an expression argument returns None.
#
# # Function Arguments
# > * ## Information can be passed into a functions as arguments.
# > * ## Arguments are specified after the function name, inside the parentheses. You can add as many arguments as you want, just seperate them with a comma.
#
# > ## Kinds of Arguments:
# > > ## 1. Positional Argument
# > > ## 2. Default Argument
# > > ## 3. Keyword Argument
#
# # Parameters or Arguments?
# > ## The term parameter and arguments can be used for the same thing: information that are passed into a function.
# > * ## Paramenter - A parameter is the variable listed inside the parentheses in the function definition.
# > * ## Argument - An argument is the value that is sent to the function when it is called.
#
# # Argument forms - Arbitrary Argument List
# ## These arguments will be wrapped up in a tuple and dictionary. Before the variable numbers of arguments, zero or more normal arguments may occur.
# > ## 1. Arbitrary Positional Arguments -> *args | tuple
# > > ## If you do not know how many arguments that will be passed into your function, add a * before the parameter name in the function definition.
# > ## 2. Arbitrary Keyword Arguments -> **args | dict
# > > ## If you do not know how many arguments that will be passed into your function, add two ** before the parameter name in the function definition.

# %%
def myfunction():
  print('myfunction called')

# %%
# calling function

myfunction()
# Out:
# myfunction called

# %%
# non-returning function

def add():
  a = 5 + 5

# %%
add()

# %%
b = add()

# %%
b

# %%
type(b)
# Out:
# NoneType

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3f786850e387> in <module>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
# using return statement

def add():
  a = 5 + 5
  return a

# %%
add()
# Out:
# 10

# %%
b = add()

# %%
b
# Out:
# 10

# %%
type(b)
# Out:
# int

# %%
add() + 5
# Out:
# 15

# %%
d = "hello! welcome to tops."

# %%
# slicing[start=0:stop=n-1:step=1]

d[:5]
# Out:
# 'hello'

# %%
d[1:8]
# Out:
# 'ello! w'

# %%
d[-1]
# Out:
# '.'

# %%
d[5:-5:]
# Out:
# '! welcome to '

# %%
d[::-1]
# Out:
# '.spot ot emoclew !olleh'

# %%
d[20:0:-1]
# Out:
# 'pot ot emoclew !olle'

# %%
d[::2]
# Out:
# 'hlo ecm otp.'

# %%
d.find('to')
# Out:
# 15

# %%
d[15]
# Out:
# 't'

# %%
d[16]
# Out:
# 'o'

# %%
d
# Out:
# 'hello! welcome to tops.'

# %%
d.find('tops') + len('tops')
# Out:
# 22

# %%
d.find('tops')
# Out:
# 18

# %%
d[18:22]
# Out:
# 'tops'

# %%
# working on ascii

ord('t')
# Out:
# 116

# %%
ord('o')
# Out:
# 111

# %%
ord('s')
# Out:
# 115

# %%
t = 'to'
r = ''
m = ''
for i in t:
  a = ord(i) - 32
  r += chr(a)
else:
  print(r)
  m = d.split(t, 1)
  m.insert(1, r)
  m = ''.join(m)
# Out:
# TO

# %%
m
# Out:
# 'hello! welcome TO tops.'

# %%
w = 'hello'
start_index = d.find(w)
if start_index >= 0:
  r = ''
  m = ''
  for i in w:
    a = ord(i) - 32
    r += chr(a)
  else:
    m = d.split(w, 1)
    m.insert(1, r)
    m = ''.join(m)
    print(m)
else:
  print(w, "not in main data.")
# Out:
# HELLO! welcome to tops.

# %%
d
# Out:
# 'hello! welcome to tops.'

# %%
d.find('hello')
# Out:
# 0

# %%
d.find('!')
# Out:
# 5

# %%
def choice_capital(word, data):
  start_index = data.find(word)
  if start_index >= 0:
    r = ''
    m = ''
    for i in word:
      a = ord(i) - 32
      r += chr(a)
    else:
      m = data.split(word, 1)
      m.insert(1, r)
      m = ''.join(m)
      return m
  else:
    print(word, "not in main data.")

# %%
choice_capital('hello', d)
# Out:
# 'HELLO! welcome to tops.'

# %%
choice_capital('come', d)
# Out:
# 'hello! welCOME to tops.'

# %%
choice_capital("xyz", 'hello! my name is xyz.')
# Out:
# 'hello! my name is XYZ.'

# %%
# arguments

# positional

def hello(name):
  print('hello', name)

# %%
hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-a75d7781aaeb> in <module>()
# ----> 1 hello()
#
# TypeError: hello() missing 1 required positional argument: 'name'

# %%
def hello(name, city):
  print('hello! I am', name, "I am from", city)

# %%
hello('meghdeep')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-82cef22e7f47> in <module>()
# ----> 1 hello('meghdeep')
#
# TypeError: hello() missing 1 required positional argument: 'city'

# %%
hello('meghdeep', 'ahmedabad')
# Out:
# hello! I am meghdeep I am from ahmedabad

# %%
# default argument

def hello(name, city=None):
  print('hello! I am', name, "I am from", city)

# %%
hello('meghdeep')
# Out:
# hello! I am meghdeep I am from None

# %%
hello('meghdeep', 'ahmedabad')
# Out:
# hello! I am meghdeep I am from ahmedabad

# %%
def hello(name, city=None):
  if city:
    print('hello! I am', name, "I am from", city)
  else:
    print('hello! I am', name)

# %%
hello('meghdeep', 'ahmedabad')
# Out:
# hello! I am meghdeep I am from ahmedabad

# %%
hello('meghdeep')
# Out:
# hello! I am meghdeep

# %%
# '', [], {}, () - These all are emply container, logically known as None means False

# %%
# keyword arguments

hello(name='meghdeep', city='ahmedabad')
# Out:
# hello! I am meghdeep I am from ahmedabad

# %%
hello(city='ahmedabad', name='meghdeep')
# Out:
# hello! I am meghdeep I am from ahmedabad

# %%
# Arbitrary Argument List

def add(x, y):
  print(x + y)

# %%
add(5,9)
# Out:
# 14

# %%
add(5,9,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2946a59e478d> in <module>()
# ----> 1 add(5,9,3)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
def add(x, y, z):
  print(x + y + z)

# %%
add(5,9,3)
# Out:
# 17

# %%
add(5,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-4f2481ea6809> in <module>()
# ----> 1 add(5,7)
#
# TypeError: add() missing 1 required positional argument: 'z'

# %%
def add(x, y, z=0):
  print(x + y + z)

# %%
add(5,7)
# Out:
# 12

# %%
add(5,7,7)
# Out:
# 19

# %%
add(5,7,7,8,9,84)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-540f73dc13d8> in <module>()
# ----> 1 add(5,7,7,8,9,84)
#
# TypeError: add() takes from 2 to 3 positional arguments but 6 were given

# %%
def arb(*x):
  print(x)

# %%
print(*"hello")
# Out:
# h e l l o

# %%
[*'hello']
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
def arb(*x):
  print(x)

# %%
arb(5,4,5,8,9)
# Out:
# (5, 4, 5, 8, 9)

# %%
def arb(*x):
  print(type(x), x)

# %%
arb(5,4,65,8)
# Out:
# <class 'tuple'> (5, 4, 65, 8)

# %%
num = (5,4,7,8,9)

# %%
s = 0
for n in num:
  s += n
else:
  print(s)
# Out:
# 33

# %%
def arb(*x):
  s = 0
  for n in x:
    s += n
  else:
    print(s)

# %%
arb(4,4,5,7)
# Out:
# 20

# %%
arb()
# Out:
# 0

# %%
def add(x, y, *z):
  s = x + y
  for n in z:
    s += n
  else:
    print(s)

# %%
add(5,4)
# Out:
# 9

# %%
add(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-e1d21b2822df> in <module>()
# ----> 1 add(5)
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
add(5,4,7)
# Out:
# 16

# %%
def add(x, y, *z):
  s = x + y
  for n in z:
    s += n
  else:
    return s

# %%
add(4,5,7,98)
# Out:
# 114

# %%
a = add(4,5,7,98)

# %%
a
# Out:
# 114

# %%
# arbitrary keyword argument list

def info(**kwargs):
  print(kwargs, type(kwargs))

# %%
info()
# Out:
# {} <class 'dict'>

# %%
info(name='nirali', city="ahmedabad")
# Out:
# {'name': 'nirali', 'city': 'ahmedabad'} <class 'dict'>

# %%
info()
# Out:
# {} <class 'dict'>

# %%
def info(name, city, **kwargs):
  print(kwargs, type(kwargs))

# %%
info(name='nirali', city="ahmedabad")
# Out:
# {} <class 'dict'>

# %%
def info(name, city, **kwargs):
  print(kwargs, type(kwargs))

# %%
info(name='nirali', city="ahmedabad", mobile="878455")
# Out:
# {'mobile': '878455'} <class 'dict'>

# %%
def info(name, city, **kwargs):
  d = {'name': name, 'city': city}
  print(kwargs, type(kwargs))

# %%
info(name='nirali', city="ahmedabad", mobile="878455")
# Out:
# {'mobile': '878455'} <class 'dict'>

# %%
def info(name, city, **kwargs):
  d = {'name': name, 'city': city}
  d.update(kwargs)
  print(d)

# %%
info(name='nirali', city="ahmedabad", mobile="878455")
# Out:
# {'name': 'nirali', 'city': 'ahmedabad', 'mobile': '878455'}

# %%
info(name='nirali', city="ahmedabad")
# Out:
# {'name': 'nirali', 'city': 'ahmedabad'}
