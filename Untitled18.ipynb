# %%
import sqlite3 as sql

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 7, 11, 10, 31, 35, 676542)

# %%
d = datetime.datetime.now()

# %%
d.day
# Out:
# 11

# %%
d.strftime('%B')
# Out:
# 'July'

# %%
d.ctime()
# Out:
# 'Mon Jul 11 10:32:10 2022'

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.mkdir("roman")

# %%
os.rmdir("roman")

# %%
file_obj = open("roman.txt" , "x")

# %%
file_obj.readable()
# Out:
# False

# %%
file_obj.write('hello word')
# Out:
# 10

# %%
file_obj.close()

# %%
file_obj.readable()
# Out:
# False

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 7, 11, 10, 50, 12, 833005)

# %%
d = datetime.datetime.now()

# %%
d.day
# Out:
# 11

# %%
d.ctime()
# Out:
# 'Mon Jul 11 10:50:37 2022'

# %%
datetime
print(d.strftime('B'))
print("date,d.strftime('y')")
print("year,d.strftime('Y')")
print("year,d.strftime('x')")
print("min,d.strftime('X')")
# Out:
# B
# date,d.strftime('y')
# year,d.strftime('Y')
# year,d.strftime('x')
# min,d.strftime('X')

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'roman.txt', 'sample_data']

# %%
file_obj = open("xyz.txt" , "x")

# %%
file_obj.write("hello word")
# Out:
# 10

# %%
file_obj.close()

# %%
file_obj = open('xyz.txt')

# %%
file_obj.read()
# Out:
# 'hello word'

# %%
file_obj.readable()
# Out:
# True

# %%
import sqlite3 as sql

# %%
db = sql.connect('xyz_db')

# %%
cur = db.cursor()

# %%
cur.execute("create table staff(id , name varchar(67) , city varchar(67));")

# %%
cur.execute("insert into staff(id , name , city) values (1 , 'roman' , 'surat');")

# %%
db.commit()

# %%
cur.execute("select * from staff")

# %%
cur.fetchall()
# Out:
# [(1, 'roman', 'surat')]

# %%
csv_file = open('roman.csv' , 'w')

# %%
data=
