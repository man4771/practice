# %%
string = "hello"

# %%
string
# Out:
# 'hello'

# %% [markdown]
# string.zfill()

# %% [markdown]
# zfill("hello")

# %%
"hello".zfill('')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-25fd6ab27994> in <module>()
# ----> 1 "hello".zfill('')
#
# TypeError: 'str' object cannot be interpreted as an integer
