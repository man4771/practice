# %%
str1 = input("enter your useraname")
str2 = input("enter your password")
username = "roman"
password = "1234"
f"username{str1} password{str2}"
if str.isalnum():
  if str == str : 
    print("true")
  else:
    print("false")
else:
  print("error")
# Out:
# enter your useranamefdghg
# enter your passwordrgfdyheh
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-f367c9a42323> in <module>()
#       4 password = "1234"
#       5 f"username{str1} password{str2}"
# ----> 6 if str.isalnum():
#       7   if str == str :
#       8     print("true")
#
# TypeError: descriptor 'isalnum' of 'str' object needs an argument

# %% [markdown]
# for i in "roman":
#   print(i)

# %%
for i in range(1,10):
  print(i , end="")
# Out:
# 123456789

# %%
for i range(1,10,-1)
  print("")

# %%
for i in range(10,0,-1):
  print(" " * (10-i) +  " * "* i)
# Out:
#  *  *  *  *  *  *  *  *  *  *
#   *  *  *  *  *  *  *  *  *
#    *  *  *  *  *  *  *  *
#     *  *  *  *  *  *  *
#      *  *  *  *  *  *
#       *  *  *  *  *
#        *  *  *  *
#         *  *  *
#          *  *
#           *

# %%
for i in range(1,10):
  print(" "* (10-i) + " * "* i)
# Out:
#           *
#          *  *
#         *  *  *
#        *  *  *  *
#       *  *  *  *  *
#      *  *  *  *  *  *
#     *  *  *  *  *  *  *
#    *  *  *  *  *  *  *  *
#   *  *  *  *  *  *  *  *  *

# %%
for i in range (10,0,-1):
  if i % 2 == 0:
    print(" "* (10-i) + " * "* i)
  else:
    print(" "* (10-i) + " # "* i)
# Out:
#  *  *  *  *  *  *  *  *  *  *
#   #  #  #  #  #  #  #  #  #
#    *  *  *  *  *  *  *  *
#     #  #  #  #  #  #  #
#      *  *  *  *  *  *
#       #  #  #  #  #
#        *  *  *  *
#         #  #  #
#          *  *
#           #

# %%
n = 10 
for i in range (1,10):
  print(f"{n} * {i} = {n*i}")
# Out:
# 10 * 1 = 10
# 10 * 2 = 20
# 10 * 3 = 30
# 10 * 4 = 40
# 10 * 5 = 50
# 10 * 6 = 60
# 10 * 7 = 70
# 10 * 8 = 80
# 10 * 9 = 90

# %%
n =15 
for i in range (1,11):
  m = f"{i}".zfill(2)
  r = f"{n*i}".zfill(3)
  print(f"{n} * {m} = {r}")
# Out:
# 15 * 01 = 015
# 15 * 02 = 030
# 15 * 03 = 045
# 15 * 04 = 060
# 15 * 05 = 075
# 15 * 06 = 090
# 15 * 07 = 105
# 15 * 08 = 120
# 15 * 09 = 135
# 15 * 10 = 150

# %%
n = 5 
for i in range (1,11):
  print(f"{n} * {i} = {n*i}")
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %% [markdown]
# n = 5
# for i in range(1,11):
#   m = f"{i}".zfill(2)
#   r = f"{n*i}".zfill(2)
#   print(f"{n} * {m} = {r}")

# %%
number = 543456

# %%
number
# Out:
# 543456

# %%
number.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-4cb7b5e75f25> in <module>()
# ----> 1 number.split()
#
# AttributeError: 'int' object has no attribute 'split'

# %%
number.split(,)
# Out:
#   File "<ipython-input-61-aad02279ad09>", line 1
#     number.split(,)
#                  ^
# SyntaxError: invalid syntax

# %%
number.split(",")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-d8b560425c5d> in <module>()
# ----> 1 number.split(",")
#
# AttributeError: 'int' object has no attribute 'split'

# %%
string = "roman"

# %%
string.split()
# Out:
# ['roman']

# %% [markdown]
# string.split(",")

# %%
numbers = 45678

# %%
numbers.split(",")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-afa8f8f3068d> in <module>()
# ----> 1 numbers.split(",")
#
# AttributeError: 'int' object has no attribute 'split'

# %%
numbers = "5,6,7,8,8"

# %%
numbers.split(",")
# Out:
# ['5', '6', '7', '8', '8']

# %%
numbers.split("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-1118e7f77fcb> in <module>()
# ----> 1 numbers.split("")
#
# ValueError: empty separator

# %%
numbers.split(",")
# Out:
# ['5', '6', '7', '8', '8']

# %%
numbers
# Out:
# '5,6,7,8,8'

# %%
numbers = numbers.split()

# %%
numbersnumbers
# Out:
# ['5,6,7,8,8']

# %%
numbers
numbers = numbers.split()

# %%
n = 16 
for i in range(1,11):
  m = f"{i}".zfill(2)
  r = f"{n*i}".zfill(3)
  print(f"{n} * {m} = {r}")
# Out:
# 16 * 01 = 016
# 16 * 02 = 032
# 16 * 03 = 048
# 16 * 04 = 064
# 16 * 05 = 080
# 16 * 06 = 096
# 16 * 07 = 112
# 16 * 08 = 128
# 16 * 09 = 144
# 16 * 10 = 160

# %%
numbers = "16,4,5,6,7"
numbers = numbers.split(",")
