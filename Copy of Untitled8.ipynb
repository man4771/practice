# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 6, 16, 10, 51, 2, 228624)

# %%
d = datetime.datetime.now()

# %%
d.day()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-070165a93cd4> in <module>()
# ----> 1 d.day()
#
# TypeError: 'int' object is not callable

# %%
d.day
# Out:
# 16

# %%
d.time
# Out:
# <function datetime.time>

# %%
d.datetimeq.time
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-a18e23ebc5c5> in <module>()
# ----> 1 d.datetimeq.time
#
# AttributeError: 'datetime.datetime' object has no attribute 'datetimeq'

# %%
d.datetime
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-c284b7fa3dc4> in <module>()
# ----> 1 d.datetime
#
# AttributeError: 'datetime.datetime' object has no attribute 'datetime'

# %%
d.strftime('%d')
# Out:
# '16'

# %%
d.strftime('%D')
# Out:
# '06/16/22'

# %%
print("current date & time and year",datetime.datetime.now(),d.strftime("%D"))
print("full in year",                d.strftime("%Y"))
print("short form in year display",  d.strftime("%y"))
print("display current date      ",  d.strftime("%d"))
print(" display the current month",  d.strftime("%m"))
print(" display the current minutes",d.strftime("%M"))
print("display month & date and year ",d.strftime("%x"))
print("display hour & min and sec",  d.strftime("%X"))
print(" mini sec                 ",  d.strftime("%f"))
print(" display the current short in  month name",d.strftime("%b"))
print("display the current full in month name",d.strftime("%B"))
print("display the short in day name",  d.strftime("%a"))
print("display the full day name",d.strftime("%A"))
# Out:
# current date & time and year 2022-06-16 11:16:40.516274 06/16/22
# full in year 2022
# short form in year display 22
# display current date       16
#  display the current month 06
#  display the current minutes 51
# display month & date and year  06/16/22
# display hour & min and sec 10:51:24
#  mini sec                  429099
#  display the current short in  month name Jun
# display the current full in month name June
# display the short in day name Thu
# display the full day name Thursday

# %%
 os.getcwd()
# Out:
# '/content'

# %%
os.listdir("c\\")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-ee0ef44ec655> in <module>()
# ----> 1 os.listdir("c\\")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c\\'

# %%
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
os.")
# Out:
#   File "<ipython-input-42-94f5dfea0963>", line 1
#     os.listdir("D:\")
#                      ^
# SyntaxError: EOL while scanning string literal

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
os.listdir(os.getcwd())
# Out:
# ['.config', 'sample_data']

# %%
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.mkdir("C:\\roman")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-52-c3963f966258> in <module>()
# ----> 1 os.mkdir("C:\\roman")
#
# FileExistsError: [Errno 17] File exists: 'C:\\roman'

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 6, 17, 9, 10, 28, 511724)

# %%
d = datetime.datetime.now()

# %%
d.day
# Out:
# 17

# %%
d.dst
# Out:
# <function datetime.dst>

# %%
d.dst()

# %%
d
# Out:
# datetime.datetime(2022, 6, 17, 9, 10, 43, 994251)

# %%
d.strftime("%X")
# Out:
# '09:10:43'

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.("c:\\")
# Out:
#   File "<ipython-input-11-f4c659313b15>", line 1
#     os.("c:\\")
#        ^
# SyntaxError: invalid syntax

# %%
os.scandir()

# %%
os.scandir()

# %%
os.listdir("c:\\")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-6c7e87759636> in <module>()
# ----> 1 os.listdir("c:\\")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\'

# %%
os.listdir("Downloads\\")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-144d34fc231c> in <module>()
# ----> 1 os.listdir("Downloads\\")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Downloads\\'

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
os.mkdir("roman")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-26-fb952e1a279f> in <module>()
# ----> 1 os.mkdir("roman")
#       2
#       3
#       4
#       5
#
# FileExistsError: [Errno 17] File exists: 'roman'

# %%
import os 
folder_path = r"C:\\Users\\Jesus\\Documents"
os.mkdir("ty")

# %%
path = "C:\\Users\\Jesus\\Documents"

# %%
import os 
os.mkdir("faisu")

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.getcwd()
# Out:
# '/content'

# %%
path
# Out:
# 'C:\\Users\\Jesus\\Documents'

# %%
import os
os.mkdir("dx")

# %%
os.listdir()
# Out:
# ['.config', 'roman', 'faisu', 'myfolder', 'dx', 'ty', 'sample_data']

# %%
import os
os.rmdir("roman")

# %%
os.scandir()

# %%
os.scandir(os.listdir())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-145db2da2b89> in <module>()
# ----> 1 os.scandir(os.listdir())
#
# TypeError: scandir: path should be string, bytes, os.PathLike, integer or None, not list

# %%
os.listdir()
# Out:
# ['.config', 'faisu', 'myfolder', 'dx', 'ty', 'sample_data']

# %%
path
# Out:
# 'C:\\Users\\Jesus\\Documents'

# %%
import os 
path = "c:\\Users\\Jesus\\Documents"
os.remove("roman.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-53-a0d78e65b766> in <module>()
#       1 import os
#       2 path = "c:\\Users\\Jesus\\Documents"
# ----> 3 os.remove("roman.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'roman.txt'

# %%
os.name
# Out:
# 'posix'

# %%
os.remove("roman.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-55-eb851ab17fa3> in <module>()
# ----> 1 os.remove("roman.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'roman.txt'

# %%
os.listdir()
# Out:
# ['.config', 'faisu', 'myfolder', 'dx', 'ty', 'sample_data']

# %%
os.listdir('c\\')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-510b6fd5fb04> in <module>()
# ----> 1 os.listdir('c\\')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c\\'

# %%
path
# Out:
# 'c:\\Users\\Jesus\\Documents'

# %%
os.listidir(path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-349d44b9142f> in <module>()
# ----> 1 os.listidir(path)
#
# AttributeError: module 'os' has no attribute 'listidir'

# %%
import os

# %%
os.listdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-63-568efd49177c> in <module>()
# ----> 1 os.listdir(path)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\Jesus\\Documents'

# %%
os.scandir()

# %%
is_file()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-45d38a162c3d> in <module>()
# ----> 1 is_file()
#
# NameError: name 'is_file' is not defined

# %%
is_file("ro,am")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-2897da50f3bb> in <module>()
# ----> 1 is_file("ro,am")
#
# NameError: name 'is_file' is not defined

# %%
path
# Out:
# 'c:\\Users\\Jesus\\Documents'

# %%
os.listidir()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-b09342b4bfe6> in <module>()
# ----> 1 os.listidir()
#
# AttributeError: module 'os' has no attribute 'listidir'

# %%
os.listdir()
# Out:
# ['.config', 'faisu', 'myfolder', 'dx', 'ty', 'sample_data']

# %%
path
# Out:
# 'c:\\Users\\Jesus\\Documents'

# %%
os.listdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-72-568efd49177c> in <module>()
# ----> 1 os.listdir(path)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\Jesus\\Documents'
