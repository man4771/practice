# %%
def arb(*z):
  s = 0
  for n in z:
    s += n
  else:
    print(s)

# %%
arb(5,6,7)
# Out:
# 18

# %%
arb('5,6,7')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-6dc478a9d962> in <module>()
# ----> 1 arb('5,6,7')
#
# <ipython-input-6-204a8fd4bf44> in arb(*z)
#       2   s = 0
#       3   for n in z:
# ----> 4     s += n
#       5   else:
#       6     print(s)
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %%
arb('5','6,'6')
# Out:
#   File "<ipython-input-9-9e95327a3c3d>", line 1
#     arb('5','6,'6')
#                 ^
# SyntaxError: invalid syntax

# %%
arb(67,87)
# Out:
# 154

# %%
def arb(x,y,*z):
  s = 0 
  for i in z:
    s += i
  else:
    return s

# %%
arb(6,7,8)
# Out:
# 8

# %%
arb(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-376ee13648a8> in <module>()
# ----> 1 arb(5)
#
# TypeError: arb() missing 1 required positional argument: 'y'

# %%
arb(5,7,8,9)
# Out:
# 17

# %%
s = arb(5,7,8,9)

# %%
s
# Out:
# 17

# %%
[**'hello']
# Out:
#   File "<ipython-input-17-8e8900db399f>", line 1
#     [**'hello']
#       ^
# SyntaxError: invalid syntax

# %%
[*'HELLO']
# Out:
# ['H', 'E', 'L', 'L', 'O']

# %%
{*'roman'}
# Out:
# {'a', 'm', 'n', 'o', 'r'}

# %%
s= {}

# %%
type(s)
# Out:
# dict

# %%
def roman(*x):
  print(x)

# %%
roman('roman')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-47fef6d2fca8> in <module>()
# ----> 1 roman('roman')
#
# TypeError: roman() takes 0 positional arguments but 1 was given

# %%
roman(**'roman')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-e1ed3b541421> in <module>()
# ----> 1 roman(**'roman')
#
# TypeError: roman() argument after ** must be a mapping, not str

# %%
roman(6,7,8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-e2b9b775a0b2> in <module>()
# ----> 1 roman(6,7,8)
#
# TypeError: roman() takes 0 positional arguments but 3 were given

# %%
roman(6,7,8,9)
# Out:
# (6, 7, 8, 9)

# %%
roman()
# Out:
# ()

# %%
def info(**roman):
  print(type(roman),roman)

# %%
 info()
# Out:
# <class 'dict'> {}

# %%
info()
# Out:
# <class 'dict'> {}

# %%
info(name='roman',place='ahmedabad')
# Out:
# <class 'dict'> {}

# %%
def info(name='roman',place='ahmedabad',**roman):
  print(type(roman),roman)

# %%
info()
# Out:
# <class 'dict'> {}

# %%
info(name='roman',place='ahmedabad')
# Out:
# <class 'dict'> {}

# %%
def info(**roman):
  print(roman)

# %%
info()
# Out:
# {}

# %%
info(name='roman',city='surat')
# Out:
# {'name': 'roman', 'city': 'surat'}

# %%
def info(city,name,**roman):
  print(roman)

# %%
info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-7a159a231d1e> in <module>()
# ----> 1 info()
#
# TypeError: info() missing 2 required positional arguments: 'city' and 'name'

# %%
info(city,name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-f0d0521b070e> in <module>()
# ----> 1 info(city,name)
#
# NameError: name 'city' is not defined

# %%
info(city,name,**roman)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-0a4a69b939aa> in <module>()
# ----> 1 info(city,name,**roman)
#
# NameError: name 'city' is not defined

# %%
info('city','name')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-f5b791a5d744> in <module>()
# ----> 1 info('city','name')
#
# <ipython-input-64-34c8e6198d8d> in info(city, name, **roman)
#       1 def info(city,name,**roman):
# ----> 2   print(type(**roman),  roman)
#
# TypeError: type() takes 1 or 3 arguments

# %%
info('city','name',**roman)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-664fd9fdf461> in <module>()
# ----> 1 info('city','name',**roman)
#
# TypeError: info() argument after ** must be a mapping, not function

# %%
info(name='roman',city='surat',moile='6789067')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-1fe19be985ba> in <module>()
# ----> 1 info(name='roman',city='surat',moile='6789067')
#
# <ipython-input-64-34c8e6198d8d> in info(city, name, **roman)
#       1 def info(city,name,**roman):
# ----> 2   print(type(**roman),  roman)
#
# TypeError: type() takes 1 or 3 arguments

# %%
def info(city,name,**roman):
  print(roman)

# %%
info(name='roman',city='surat',mobil='896788')
# Out:
# {'mobil': '896788'}

# %%
info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-7a159a231d1e> in <module>()
# ----> 1 info()
#
# TypeError: info() missing 2 required positional arguments: 'city' and 'name'
