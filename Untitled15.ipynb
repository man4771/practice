# %%
# single
class student_info:
  def student_data(self,name,roll_no,mobile_no,address):
    self.name = "roman"
    self.roll_no = 35
    self.mobile_no = 567890
    self.address = "ahmedabad"
    print(self)

class college_info(student_info):
  def college_data(self,clg_name,clg_contact_number,clg_email_id):
    self.clg_name = "xyz"
    self.clg_contact_number = 56788964346
    self.clg_email_id = "xyz@gmail.com"
    
  def college_data(self):
    return

# %%
c = college_info()

# %%
c.student_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-99f5dc6e9212> in <module>()
# ----> 1 c.student_data()
#
# TypeError: student_data() missing 4 required positional arguments: 'name', 'roll_no', 'mobile_no', and 'address'
