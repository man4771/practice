# %%
#What is File function in python? What is keywords to create and write file.
'''x' - create a new file.
w' - Write Mode: This mode is used when you want to write data into the file or modify it. Remember, write mode overwrites the data present in the file.'''
file_obj = open("myfile.txt" , "x")
file_obj.write("hello tops")
# Out:
# 10

# %%
#Write a Python program to read an entire text file.
file_obj.close()
file_obj = open("myfile.txt")
file_obj.read()
# Out:
# 'hello tops'

# %%
#Write a Python program to append text to a file and display the te
file_obj = open("abc.txt" , "w")
l = ("this is file \n","this is the file1 \n","this is file2")
file_obj.writelines(l)
file_obj.close()
file_obj = open("abc.txt" , "a")
file_obj.write("today \n")
file_obj.close()
file_obj = open("abc.txt")
file_obj.read()
# Out:
# 'this is file \nthis is the file1 \nthis is file2today \n'

# %%
#Write a Python program  read first n lines of a file
file_obj = open("abc.txt" , "r")
file_obj.readlines(1)
# Out:
# ['this is file \n']

# %%
#Write a Python program to read last n lines of a file.
def file_obj(fname,n):
  with open("abc.txt") as f:
    for line in (f.readlines() [-n:] ):
      print(line)
file_obj("abc.txt" , 3)
# Out:
# this is file
#
# this is the file1
#
# this is file2today
