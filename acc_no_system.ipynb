# %%
data = {'username' : "roman@gmail.com" , 'password': '4771'}
username = input('enter the username')
if username == data['username']:
    password = input('enter the password')
    password.isnumeric()
    password = int(password)
    if password == data['password']:
        print("login success")
    else:
         print("incorrect password")
else:
    print("enter the valid username")
# Out:
# enter the username1234
# enter the valid username

# %%
bank = [{'acco_no' : 1234 , 'holder_name' : 'roman' , 'pin' : 4771 , 'balance' : 10000.00},
        {'acco_no' : 5678 , 'holder_name' : 'ajay' , 'pin' : 4772 , 'balance' : 20000.00},
        {'acco_no' : 9012 , 'holder_name' : 'sanjay' , 'pin' : 4773 , 'balance' : 30000.00},
        {'acco_no' : 3456 , 'holder_name' : 'rahul' , 'pin' : 4774 , 'balance' : 40000.00},
        {'acco_no' : 7890 , 'holder_name' : 'kiran' , 'pin' : 4775 , 'balance' : 50000.00}]

# %%
bank = [{'acco_no' : 1234 , 'holder_name' : 'roman' , 'pin' : 4771 , 'balance' : 10000.00},
        {'acco_no' : 5678 , 'holder_name' : 'ajay' , 'pin' : 4772 , 'balance' : 20000.00},
        {'acco_no' : 9012 , 'holder_name' : 'sanjay' , 'pin' : 4773 , 'balance' : 30000.00},
        {'acco_no' : 3456 , 'holder_name' : 'rahul' , 'pin' : 4774 , 'balance' : 40000.00},
        {'acco_no' : 7890 , 'holder_name' : 'kiran' , 'pin' : 4775 , 'balance' : 50000.00}]
acco_no = input('enter the account number')
acco_no.isnumeric()                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
if acco_no == bank['acco_no']:
acco_no = int(acco_no) 
  print(f"welcome{bank['acco_no']}")
  pin = input('enter the pin')
  pin.isnumeric()
  if pin == bank['pin']:
  pin = int(pin)
     print(f"your balance{bank['balance']}")
  else:
    print("incorrect pin")
else:
  print("invalid input")
# Out:
#   File "<ipython-input-1-5eaa732e16aa>", line 9
#     acco_no = int(acco_no)
#           ^
# IndentationError: expected an indented block

# %%
type(bank)
# Out:
# list

# %%
bank = int(bank)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-2f6ad0f29c7e> in <module>()
# ----> 1 bank = int(bank)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
int = int(bank)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-068df221ea4b> in <module>()
# ----> 1 int = int(bank)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
int(bank)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-5f46a3388fe7> in <module>()
# ----> 1 int(bank)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
bank = int(bank)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-2f6ad0f29c7e> in <module>()
# ----> 1 bank = int(bank)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
bank = str(bank)

# %%
bank = int(bank)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-2f6ad0f29c7e> in <module>()
# ----> 1 bank = int(bank)
#
# ValueError: invalid literal for int() with base 10: "[{'acco_no': 1234, 'holder_name': 'roman', 'pin': 4771, 'balance': 10000.0}, {'acco_no': 5678, 'holder_name': 'ajay', 'pin': 4772, 'balance': 20000.0}, {'acco_no': 9012, 'holder_name': 'sanjay', 'pin

# %%
bank = str(bank)

# %%
file = {'acco_no' : 1234 , 'holder_name' : 'roman' , 'pin' : 4771 , 'balance' : 10000.00},
        {'acco_no' : 5678 , 'holder_name' : 'ajay' , 'pin' : 4772 , 'balance' : 20000.00},
        {'acco_no' : 9012 , 'holder_name' : 'sanjay' , 'pin' : 4773 , 'balance' : 30000.00},
        {'acco_no' : 3456 , 'holder_name' : 'rahul' , 'pin' : 4774 , 'balance' : 40000.00},
        {'acco_no' : 7890 , 'holder_name' : 'kiran' , 'pin' : 4775 , 'balance' : 50000.00}
# Out:
#   File "<ipython-input-27-cb6cc761d2cb>", line 2
#     {'acco_no' : 5678 , 'holder_name' : 'ajay' , 'pin' : 4772 , 'balance' : 20000.00},
#     ^
# IndentationError: unexpected indent

# %%
f = {
    {
    'acco_no' : 1234 , 
     'holder_name' : 'roman', 
     'pin' : 4771 ,
     'balance' : 10000.00,
    },
    {
      'acco_no' : 5678 ,  
      'holder_name' : 'ajay',
      'pin' : 4772 ,
      'balance' : 20000.00,
    }
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-e54761fc0c1b> in <module>()
#      10       'holder_name' : 'ajay',
#      11       'pin' : 4772 ,
# ---> 12       'balance' : 20000.00,
#      13     }
#      14 }
#
# TypeError: unhashable type: 'dict'

# %%
Q
