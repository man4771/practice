# %%
t = [5,6,7]

# %%
t = tuple(t)

# %%
x = (3,4,5,6,7)

# %%
x.reverse()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-1cc9031a0932> in <module>()
# ----> 1 x.reverse()
#
# AttributeError: 'tuple' object has no attribute 'reverse'
