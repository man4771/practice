# %%
import sqlite3 as sql

# %%
db = sql.connect("python_sqlite3_db")

# %%
cur = db.cursor()

# %%
cur.execute("create table employee(id int , name varchar(45) , city varchar(56));")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-8-79d9f3ecdfe5> in <module>()
# ----> 1 cur.execute("create table employee(id int , name varchar(45) , city varchar(56));")
#
# OperationalError: table employee already exists

# %%
cur.execute("insert into employee(id , name , city) values (1 , 'roman' , 'ahemdabad');")

# %%
db.commit()

# %%
db.fetc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-a2b9f59e6c4d> in <module>()
# ----> 1 db.fetchall()
#
# AttributeError: 'sqlite3.Connection' object has no attribute 'fetchall'

# %%
cur.execute("select * from employee")

# %%
cur.fetchall()
# Out:
# [(1, 'roman', 'ahemdabad')]

# %%
cur.execute("update employee set name='ajay' where id=1")

# %%
db.commit()

# %%
cur.execute("select * from employee")

# %%
cur.fetchall()
# Out:
# [(1, 'ajay', 'ahemdabad')]

# %%
cur.execute("insert into employee(id , name , city) values (2 , 'roman' , 'surat')")

# %%
db.commit()

# %%
cur.execute("select * from employee")

# %%
cur.fetchall()
# Out:
# [(1, 'ajay', 'ahemdabad'), (2, 'roman', 'surat')]

# %%
cur.excute("delete from emloyee where pi)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-36c0129548a5> in <module>()
# ----> 1 cur.excute("delete from emloyee where 'ajay")
#
# AttributeError: 'sqlite3.Cursor' object has no attribute 'excute'

# %%
cur.execute("alter table employee add pincode int ")

# %%
db.commit()

# %%
cur.execute("select * from employee")

# %%
cur.fetchall()
# Out:
# [(1, 'ajay', 'ahemdabad', None), (2, 'roman', 'surat', None)]

# %%
cur.execute("insert into employee(id , name , city) values (4 , 'jay' , 'baroda')")

# %%
cur.commit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-5f9fa7ab84b4> in <module>()
# ----> 1 cur.commit()
#
# AttributeError: 'sqlite3.Cursor' object has no attribute 'commit'

# %%
cur.execute("select * from employee")

# %%
cur.fetchall()
# Out:
# [(1, 'ajay', 'ahemdabad', None),
#  (2, 'roman', 'surat', None),
#  (4, 'jay', 'baroda', None)]

# %%
cur.execute("update employee set pincode=1234 where id=1")

# %%
db.commit()

# %%
cur.execute("drop database python_sqlite3_db")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-59-b550d6f3aa20> in <module>()
# ----> 1 cur.execute("drop database 'python_sqlite3_db'")
#
# OperationalError: near "database": syntax error
