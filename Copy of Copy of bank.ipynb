# %%
bank_schema = {
    67498545: {
        'pin': 4567,
        'balance': 10000.00,
        'holder_name': 'nirali',
        'transactions': [{
            'amount': 100.00,
            'type': 'dr',
            'datetime': object,
        }]
    },
    67498546: {},
    67498547: {},
}
preset_acc_number = 34567543000
acc_details = {
    'acc_holder' : str(),
    'pin' : int(),
    'balance' : float(),
    'transaction' : [],
}

transaction_details = {
    'amount' : int(),
    'tr_type' : str(),
    'datetime' : object(),
}

bank = dict()

# %%
def new_acc_number(preset_acc_number,bank):
  acc_num = preset_acc_number + len(bank) + 1
  return acc_num
  bank.setdefault(acc_num , acc_details.copy())

# %%
new_acc_number(34567543000,bank)
# Out:
# 34567543003

# %%
bank
# Out:
# {34567543001: {'acc_holder': '', 'balance': 0.0, 'pin': 0, 'transaction': []},
#  34567543002: {'acc_holder': '', 'balance': 0.0, 'pin': 0, 'transaction': []}}

# %%
bank[34567543001]
# Out:
# {'acc_holder': '', 'balance': 0.0, 'pin': 0, 'transaction': []}

# %%
def preset_acc_details(holder_name,pin,balance,transaction=list(),**others):
  preset_acc_details = {
      'holder_name' : 'roman',
      'pin'         :  1234,
      'balance'     :  10000,
      'transaction' :  '',
  }

  for k,v in others.items():
    print(preset_acc_details.setdefault(k,v))
  return preset_acc_details

# %%
preset_acc_details('rohit',4771,10000,city='surat')
# Out:
# surat
# {'balance': 10000,
#  'city': 'surat',
#  'holder_name': 'roman',
#  'pin': 1234,
#  'transaction': ''}

# %%
preset_acc_details('roman',4771,10000)
# Out:
# <function __main__.preset_acc_details>

# %%
def transaction_details(amount,tr_type,date_time,**others):
  tr_preset = {
      'amount' : amount,
      'tr_type' : 'cr',
      'datetime' : date_time ,
  }
  for k,v in others.items():
    print(tr_preset.setdefault(k,v))
  return tr_preset

# %%
def deposite_balance(preset_acc_number,balance):
  bank[34567543001]['balance'] += 5000.0
  


bank['transaction']

# %%
transaction_details(10000.0,'cr',5678)
# Out:
# {'amount': 10000.0, 'datetime': 5678, 'tr_type': 'cr'}

# %%
import datetime
def transaction_viewer(tr_obj):
  s = '║'
  for key in tr_obj.keys():
    s += key.center(10) + '\t║\t'
    
  s = s.rstrip()

  print("╔═══════════════","═══════════════════════","═══════════════════════",sep="╦",end="╗")
  print()

  print(s)
  sep = '════════════════╬' #len(s) * 2
  # print(len(sep))

  # for i in range(1,5):
  print("╠═══════════════","═══════════════════════","═══════════════════════",sep="╬",end="╣")

  print()

  print("║", end="")
  for k,v in tr_obj.items():
    if k == 'datetime':
      print(f"{v.strftime('%x %X')}", end='║'.ljust(14))
    else:
      print(f"{v}  ".center(9), end='║'.center(14))
  else:
    print("\n╠═══════════════","═══════════════════════","═══════════════════════",sep="╬",end="╣")
  print()

# %%
acc_num = preset_acc_details + len(bank) + 1
print(acc_num)
bank.setdefault(acc_num.acc_details.copy())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-64e605d9e7b8> in <module>()
# ----> 1 acc_num = preset_acc_details + len(bank) + 1
#       2 print(acc_num)
#       3 bank.setdefault(acc_num.acc_details.copy())
#
# TypeError: unsupported operand type(s) for +: 'function' and 'int'

# %%
import datetime
def deposite(acc_num,amount):
  bank[acc_num]['balance'] += amount
  transaction = transaction_details('cr',datetime.datetime.now(),amount)
  bank[acc_num]['transaction'].append(transaction)
  transaction_viewer(transaction)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-b2fd7f98f3b2> in <module>()
# ----> 1 deposite_balance(acc_num,5000)
#
# NameError: name 'acc_num' is not defined

# %%
transaction_viewer(transaction_details(565,'cr'):
# Out:
#   File "<ipython-input-1-13ed07267f68>", line 1
#     transaction_viewer(transaction_details(565,'cr'):
#                                                     ^
# SyntaxError: invalid syntax

# %%
acc_details = (preset_acc_details('rohit',4771,10000,city='surat'))

bank.setdefault(acc_num, acc_details)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-bbc23cede759> in <module>()
# ----> 1 acc_details = (preset_acc_details('rohit',4771,10000,city='surat'))
#       2
#       3 bank.setdefault(acc_num, acc_details)
#
# NameError: name 'preset_acc_details' is not defined

# %%
acc_num = new_acc_number(preset_acc_number, bank)
bank_details = acc_details('suyog', 7345,balance = float(), city='ahmedabad')

bank.setdefault(acc_num, acc_details)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-de1318d5b646> in <module>()
# ----> 1 acc_num = new_acc_number(preset_acc_number, bank)
#       2 bank_details = acc_details('suyog', 7345,balance = float(), city='ahmedabad')
#       3
#       4 bank.setdefault(acc_num, acc_details)
#
# NameError: name 'preset_acc_number' is not defined
