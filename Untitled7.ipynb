# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 6, 16, 9, 47, 7, 12431)

# %%
d = datetime.datetime.now()

# %%
d
# Out:
# datetime.datetime(2022, 6, 16, 9, 47, 55, 491050)

# %%
d.day
# Out:
# 16

# %%
d.datetime("%X")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-ce2f539ec12d> in <module>()
# ----> 1 d.datetime("%X")
#
# AttributeError: 'datetime.datetime' object has no attribute 'datetime'

# %%
d.ctime()
# Out:
# 'Thu Jun 16 09:47:55 2022'

# %%
d.ctime("%X")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4e47160db759> in <module>()
# ----> 1 d.ctime("%X")
#
# TypeError: ctime() takes no arguments (1 given)

# %%
d.day()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-220f3957c7c9> in <module>()
# ----> 1 d.day()
#       2
#
# TypeError: 'int' object is not callable

# %%
d.strftime('%d')
# Out:
# '16'

# %%
d.strftime('%D')
# Out:
# '06/16/22'

# %%
d.strftime("%x")
# Out:
# '06/16/22'

# %%
strfmonth('%D')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-77a52aaa9c64> in <module>()
# ----> 1 strfmonth('%D')
#
# NameError: name 'strfmonth' is not defined

# %%
d.strftime('%d')
# Out:
# '16'

# %%
d.strftime("%f")
# Out:
# '491050'

# %%
d.strftime('%M')
# Out:
# '47'

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 6, 16, 9, 54, 39, 352863)

# %%
d.strftime("%d,%X,%y,%Y,%M,%m,%x,%X")
# Out:
# '16,09:47:55,22,2022,47,06,06/16/22,09:47:55'

# %%
import os
