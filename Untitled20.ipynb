# %%
# bank example

# bank = [{},{},{}]

bank_schema = {
    67498545: {
        'pin': 4567,
        'balance': 10000.00,
        'holder_name': 'nirali',
        'transactions': [{
            'amount': 100.00,
            'type': 'dr',
            'datetime': object,
        }]
    },
    67498546: {},
    67498547: {},
}

# %%
# preset account number

preset_acc_number = 1024598701000

transaction_preset = {
    'amount': float(),
    'tr_type': str(),
    'datetime': object
}

bank_acc_details = {
    'pin': int(),
    'acc_holder': str(),
    'balance': float(),
    'transactions': []
}

bank = dict()

# %%
def new_acc_num(bank):
  new_acc_num = preset_acc_number + len(bank) + 1
  bank.setdefault(new_acc_num,bank_acc_details.copy())
  return new_acc_num

# %%
def bank_acc_details():
  bank_acc_details = {
      'ácc_holder' : 'roman',
      'pin' : 1234,
      'balance' : 1000.0,

  }
  bank_acc_details.update()
  return bank_acc_details
  acc_holder = input("enter your name")
  if acc_holder == acc_holder:
    pin = input("enter your pin")
    pin.isnumeric()
    pin = int(pin)
    if pin == pin:
      balance = input("enter the amount")
      balance.isnumeric()
      balance = int(balance)
      if balance == balance:
        print
        print(f"{new_acc_num(bank)}")
  else:
    print("sorry")

# %%
new_acc()
# Out:
# enter your nameroman
# enter your pin1234
# enter the amount1000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-f6a8f06c85ff> in <module>()
# ----> 1 new_acc()
#       2
#       3
#       4
#       5
#
# <ipython-input-14-2f9cb14bd16d> in new_acc()
#      10       balance = int(balance)
#      11       if balance == balance:
# ---> 12         print(f"{new_acc_num(bank)}")
#      13   else:
#      14     print("sorry")
#
# <ipython-input-13-67fd95282673> in new_acc_num(bank)
#       1 def new_acc_num(bank):
#       2   new_acc_num = preset_acc_number + len(bank) + 1
# ----> 3   bank.setdefault(new_acc_num,bank_acc_details.copy())
#       4   return new_acc_num
#       5
#
# AttributeError: 'function' object has no attribute 'copy'

# %%
bank
# Out:
# {1024598701001: {'acc_holder': '',
#   'balance': 0.0,
#   'pin': 0,
#   'transactions': []}}

# %%
def check_balance(preset_acc_number):
  if preset_acc_number == bank['balance']:
    print(f"{bank['balance']}")
  return check_balance

# %%
check_balance(1024598701001)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-ab20571b5be4> in <module>()
# ----> 1 check_balance(1024598701001)
#
# <ipython-input-18-64a2b9c43c3c> in check_balance(preset_acc_number)
#       1 def check_balance(preset_acc_number):
# ----> 2   if preset_acc_number == bank['balance']:
#       3     print(f"{bank['balance']}")
#       4   return check_balance
#
# KeyError: 'balance'
