# %%
type(dr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8a3dffde5a98> in <module>()
# ----> 1 type(dr)
#
# NameError: name 'dr' is not defined

# %%
class hello:
  name = 'roman'

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9bc0cb2ed6de> in <module>()
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
class.name
# Out:
#   File "<ipython-input-4-a19bd9af11c2>", line 1
#     class.name
#          ^
# SyntaxError: invalid syntax

# %%
class hello:
# Out:
#   File "<ipython-input-6-11930057de0f>", line 1
#     class hello:
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
class hello:
  name = 'roman'

# %%
o = hello

# %%
o.name
# Out:
# 'roman'

# %%
type = dir(o)

# %%
class hello:
  name = 'roman'

# %%
class hello:
  print('welcome to the ')
# Out:
# welcome to the

# %%
hello()

# %%
hello:
# Out:
#   File "<ipython-input-14-05d07803fcb1>", line 1
#     hello:
#           ^
# SyntaxError: invalid syntax

# %%
hello
# Out:
# __main__.hello

# %%
o = hello

# %%
o.address = 'surat'

# %%
o
# Out:
# __main__.hello

# %%
class hello:
  def __init__(self):
      self.name = 'roman'
      print('conduct')

# %%
o = hello()
# Out:
# conduct

# %%
hello()
# Out:
# conduct

# %%
self = o

# %%
o.name
# Out:
# 'roman'

# %%
class cal:
  def __init__(self,x,y):
    print(x,y)

# %%
class cal:
  def __init__(self,x,y):
    self.x = x
    self.y = y
    print(x,y)
  
  def add(self):
    return self.x + self.y

# %%
o = cal(6,7)
# Out:
# 6 7

# %%
o.(5,6)
# Out:
#   File "<ipython-input-36-2e942ed661ce>", line 1
#     o.(5,6)
#       ^
# SyntaxError: invalid syntax

# %%
o.cal(6,7)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-ff5642e3cbcc> in <module>()
# ----> 1 o.cal(6,7)
#
# AttributeError: 'cal' object has no attribute 'cal'

# %%
o.add()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-58cc84428327> in <module>()
# ----> 1 o.add()
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
o = cal(6,7)
# Out:
# 6 7

# %%
o.x
# Out:
# 6

# %%
o.y
# Out:
# 7

# %%
o.add()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-58cc84428327> in <module>()
# ----> 1 o.add()
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
o = cal(5,5)
# Out:
# 5 5

# %%
o.x
# Out:
# 5

# %%
o.y
# Out:
# 5

# %%
o.add()
# Out:
# 10

# %%
bank_scheme= {67498545: {'pin': 4567,'balance': 10000.00,'holder_name': 'nirali','transactions': [{'amount': 100.00,'type': 'dr','datetime': object,}]},67498546: {},67498547: {},
}

bank = {}

# %%
s = '║'
for key in bank[1024598701001]['transactions'][0].keys():
  s += key.center(10) + '\t║\t'
  
s = s.rstrip()

print("╔═══════════════","═══════════════════════","═══════════════════════",sep="╦",end="╗")
print()

print(s)
sep = '════════════════╬' #len(s) * 2
# print(len(sep))

# for i in range(1,5):
print("╠═══════════════","═══════════════════════","═══════════════════════",sep="╬",end="╣")

print()

for tr in bank[1024598701001]['transactions']:
  print("║", end="")
  for k,v in tr.items():
    if k == 'datetime':
      print(f"{v.strftime('%x %X')}", end='║'.ljust(14))
    else:
      print(f"{v}  ".center(9), end='║'.center(14))
  else:
    print("\n╠═══════════════","═══════════════════════","═══════════════════════",sep="╬",end="╣")
  print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-a8952f14ef96> in <module>()
#       1 s = '║'
# ----> 2 for key in bank[1024598701001]['transactions'][0].keys():
#       3   s += key.center(10) + '\t║\t'
#       4
#       5 s = s.rstrip()
#
# NameError: name 'bank' is not defined

# %%
class cal:
  def __init__(self,x,y):
    self.x = x
    self.y = y
    print(x,y)
    
  def add(self):
    return self.x + self.y

# %%
o = cal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-126189e69dac> in <module>()
# ----> 1 o = cal()
#
# TypeError: __init__() missing 2 required positional arguments: 'x' and 'y'

# %%
 o =cal(6,7)
# Out:
# 6 7

# %%
o.add()
# Out:
# 13

# %%
bank =  {'acc_no' : 1234 {'holder_name' : 'roman' }}
acc_no = input('enter the accound number')
if acc_no =

# %%
info = {'username' : 'roman@gmail.com' , 'password' : 1234}
username = input('enter the username')
username.isalnum()
if username == info['username']:
  password = input("enter the password")
  password.isnumeric()
  password = int(password)
  if password == info['password']:
    print("succuess")
  else:
    print("invalid passwrod")
else:
  print("input error")
# Out:
# enter the usernameroman@gmail.com
# enter the password1234
# succuess

# %%
hello
# Out:
# __main__.hello

# %%
t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-2bcdac14831c> in <module>()
# ----> 1 t
#
# NameError: name 't' is not defined

# %%
print('hello')
# Out:
# hello

# %%
print('hello/tword')
# Out:
# hello/tword

# %%
print(hello/tword)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-ae0790b91da9> in <module>()
# ----> 1 print(hello/tword)
#
# NameError: name 'tword' is not defined

# %%
s = [5,6,7,8]

# %%
s.append(4)

# %%
s
# Out:
# [5, 6, 7, 8, 4]

# %%
s.extend[(5,6,7,8)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-bb4c0fee1eaa> in <module>()
# ----> 1 s.extend[(5,6,7,8)]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
s.extend[(5,6,6)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-e91bccfe0ee9> in <module>()
# ----> 1 s.extend[(5,6,6)]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
s.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-0df5f5b6357e> in <module>()
# ----> 1 s.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
s.extend[(5,6,7)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-3dc5a8f2b4de> in <module>()
# ----> 1 s.extend[(5,6,7)]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
type(s)
# Out:
# list

# %%
s
# Out:
# [5, 6, 7, 8, 4]

# %%
s.sort()

# %%
s
# Out:
# [4, 5, 6, 7, 8]

# %%
s.sort(reverse = True)

# %%
s
# Out:
# [8, 7, 6, 5, 4]
