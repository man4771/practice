# %%
def roman():
    print('function')

# %%
roman()
# Out:
# function

# %%
roman()
# Out:
# function

# %%
numbers = '6,7,8,89,9'
temp = ''
for n in numbers.split(',')
  if n not in temp:
# Out:
#   File "<ipython-input-13-5b06d15190cb>", line 3
#     for n in numbers.split(',')
#                                ^
# SyntaxError: invalid syntax

# %%
numbers = '54,5,6,7'
numbers =  numbers.split(',')
for i in range(1,11):
  for nums in numbers:
    m = f'{i}'.zfill(2)
    n = int(nums)
    r = f'{n*i}'.zfill(2)

    print(f'{n} * {m} = {r}' , end = '\t|\t')
  else:
     print()
# Out:
# 54 * 01 = 54	|	5 * 01 = 05	|	6 * 01 = 06	|	7 * 01 = 07	|
# 54 * 02 = 108	|	5 * 02 = 10	|	6 * 02 = 12	|	7 * 02 = 14	|
# 54 * 03 = 162	|	5 * 03 = 15	|	6 * 03 = 18	|	7 * 03 = 21	|
# 54 * 04 = 216	|	5 * 04 = 20	|	6 * 04 = 24	|	7 * 04 = 28	|
# 54 * 05 = 270	|	5 * 05 = 25	|	6 * 05 = 30	|	7 * 05 = 35	|
# 54 * 06 = 324	|	5 * 06 = 30	|	6 * 06 = 36	|	7 * 06 = 42	|
# 54 * 07 = 378	|	5 * 07 = 35	|	6 * 07 = 42	|	7 * 07 = 49	|
# 54 * 08 = 432	|	5 * 08 = 40	|	6 * 08 = 48	|	7 * 08 = 56	|
# 54 * 09 = 486	|	5 * 09 = 45	|	6 * 09 = 54	|	7 * 09 = 63	|
# 54 * 10 = 540	|	5 * 10 = 50	|	6 * 10 = 60	|	7 * 10 = 70	|

# %%
for i in range(1,11):
  print(' * ' * i)
# Out:
#  *
#  *  *
#  *  *  *
#  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *  *
#  *  *  *  *  *  *  *
#  *  *  *  *  *  *  *  *
#  *  *  *  *  *  *  *  *  *
#  *  *  *  *  *  *  *  *  *  *

# %%
for i in range(11,0,-1):
  if i % 2 == 0:
    print('' * (i-10) + ' * ' * i)
  else:
    print('' * (i-10) + ' # ' * i)
# Out:
#  #  #  #  #  #  #  #  #  #  #  #
#  *  *  *  *  *  *  *  *  *  *
#  #  #  #  #  #  #  #  #  #
#  *  *  *  *  *  *  *  *
#  #  #  #  #  #  #  #
#  *  *  *  *  *  *
#  #  #  #  #  #
#  *  *  *  *
#  #  #  #
#  *  *
#  #

# %%
numbers = input('enter the numbers')
numbers = numbers.split(',')
for i in range(1,11):
  for nums in numbers:
    m = f'{i}'.zfill(2)
    r = f'{n*i}'.zfill(2)
    n = int(nums)

    print(f'{n} * {m} = {r}' , end = '\t|\t')
  else:
    print()
# Out:
# enter the numbers5,6,7,8
# 5 * 01 = 07	|	6 * 01 = 05	|	7 * 01 = 06	|	8 * 01 = 07	|
# 5 * 02 = 16	|	6 * 02 = 10	|	7 * 02 = 12	|	8 * 02 = 14	|
# 5 * 03 = 24	|	6 * 03 = 15	|	7 * 03 = 18	|	8 * 03 = 21	|
# 5 * 04 = 32	|	6 * 04 = 20	|	7 * 04 = 24	|	8 * 04 = 28	|
# 5 * 05 = 40	|	6 * 05 = 25	|	7 * 05 = 30	|	8 * 05 = 35	|
# 5 * 06 = 48	|	6 * 06 = 30	|	7 * 06 = 36	|	8 * 06 = 42	|
# 5 * 07 = 56	|	6 * 07 = 35	|	7 * 07 = 42	|	8 * 07 = 49	|
# 5 * 08 = 64	|	6 * 08 = 40	|	7 * 08 = 48	|	8 * 08 = 56	|
# 5 * 09 = 72	|	6 * 09 = 45	|	7 * 09 = 54	|	8 * 09 = 63	|
# 5 * 10 = 80	|	6 * 10 = 50	|	7 * 10 = 60	|	8 * 10 = 70	|

# %%
def function():
  a = 5 + 4
  return a

# %%
function()
# Out:
# 9

# %%
a = a + 8
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-096c0ae7d425> in <module>()
# ----> 1 a = a + 8
#
# NameError: name 'a' is not defined

# %%
function(a + 6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-7e76c8959b54> in <module>()
# ----> 1 function(a + 6)
#
# NameError: name 'a' is not defined

# %%
function() + 6
# Out:
# 15

# %%
def  roman(name,place):
  print('my name is',name,'im frome',place)

# %%
roman(name,place)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-ea42ffe994c4> in <module>()
# ----> 1 roman(name,place)
#
# NameError: name 'name' is not defined

# %%
roman('roman','ahmedabad')
# Out:
# my name is roman im frome ahmedabad

# %%
def function(name , place=none):
  for place:
    print('my name is',name,'im frome',place)
  else:
    print('my name is',name,'im frome',place)
# Out:
#   File "<ipython-input-49-c6e287cc6a6a>", line 2
#     for place:
#              ^
# SyntaxError: invalid syntax

# %%
def function(name,place=None):
  print('my name is',name,'im frome',place)

# %%
def hello(name, city=None):
  print('hello! I am', name, "I am from", city)

# %%
funtion('roman')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-dac9f29be0c4> in <module>()
# ----> 1 funtion('roman')
#
# NameError: name 'funtion' is not defined

# %%
function('roman','ahmedabad')
# Out:
# my name is roman im frome ahmedabad

# %%
function('ROMAN')
# Out:
# my name is ROMAN im frome None

# %%
def function(name,place=None):
  if place:
        print('my name is',name,'im frome',place)
  else:
        print('my name is',name)

# %%
function('roman')
# Out:
# my name is roman

# %%
function('roman','surat')
# Out:
# my name is roman im frome surat

# %%
function('surat')
# Out:
# my name is surat

# %%
def funtion(x,y):
  print(x + y)

# %%
function(4,5)
# Out:
# my name is 4 im frome 5

# %%
def f(x,y):
  print(x + y)

# %%
f(6,7)
# Out:
# 13

# %%
def arb(*x):
  print(x)

# %%
arb(6,7,8,4,5)
# Out:
# (6, 7, 8, 4, 5)

# %%
def arb(*x):
  s = 0
  for n in x:
    s += n
  else:
    print(s)

# %%
arb(6,7,8,9)
# Out:
# 30

# %%
[*hello]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-1341ab1dc9be> in <module>()
# ----> 1 [*hello]
#
# TypeError: 'function' object is not iterable

# %%
[*'hello']
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
i =  (6,7,8,)

# %%
type(I)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-2e2a4d8dca49> in <module>()
# ----> 1 type(I)
#
# NameError: name 'I' is not defined

# %%
type(i)
# Out:
# tuple

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s = {'name':'roman','marks':{'maths':56,'english':78,'hindi':78}}

# %%
d = {'name':'dev','marks':{'maths':78,'english':45,'hindi':78}}

# %%
s = {'name':'pratik','marks':{'maths':56,'english':20,'hindi':67}}

# %%
t = [{'name':'roman','marks':{'maths':56,'english':78,'hindi':78}},
     {'name':'dev','marks':{'maths':78,'english':45,'hindi':78}},
     {'name':'pratik','marks':{'maths':56,'english':20,'hindi':67}}]

# %%
t
# Out:
# [{'marks': {'english': 78, 'hindi': 78, 'maths': 56}, 'name': 'roman'},
#  {'marks': {'english': 45, 'hindi': 78, 'maths': 78}, 'name': 'dev'},
#  {'marks': {'english': 20, 'hindi': 67, 'maths': 56}, 'name': 'pratik'}]

# %%
def arb(x,y,*z):
  if n in z:
    s = x + y
  else:
    print(s)

# %%
arb(5,6)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-94-e16d1c741344> in <module>()
# ----> 1 arb(5,6)
#
# <ipython-input-93-254fa29a7696> in arb(x, y, *z)
#       3     s = x + y
#       4   else:
# ----> 5     print(s)
#       6
#
# UnboundLocalError: local variable 's' referenced before assignment

# %%
arb('5','6')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-95-b40b7eb18e7c> in <module>()
# ----> 1 arb('5','6')
#
# <ipython-input-93-254fa29a7696> in arb(x, y, *z)
#       3     s = x + y
#       4   else:
# ----> 5     print(s)
#       6
#
# UnboundLocalError: local variable 's' referenced before assignment

# %%
def arb(*x):
  s = 0
  if n in x:
    s += n

  else:
    print(s)

# %%
arb(6,7,8,9,9)

# %%
arb(6,7,8,9)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-103-2efcbeb54dba> in <module>()
# ----> 1 arb(6,7,8,9)
#
# <ipython-input-101-d3e65f214ef9> in arb(*x)
#       1 def arb(*x):
#       2   if n in x:
# ----> 3     s += n
#       4
#       5   else:
#
# UnboundLocalError: local variable 's' referenced before assignment

# %%
def arb(*x):
  s = 0
  if n in x:
    s += n
  else:
    print(s)

# %%
arb(6,7,8,9)

# %%
def arb(*x):
  print(x)

# %%
arb('hello')
# Out:
# ('hello',)

# %%
arb(6,7,8,9)
# Out:
# (6, 7, 8, 9)

# %%
arb('hello')
# Out:
# ('hello',)

# %%
def arb(*z):
  s = 0
  if n in z:
    s += n
  else:
    print(s)

# %%
arb(6,7,8,9,56)

# %%
info(name='roman',city='surat')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-cf00765e831a> in <module>()
# ----> 1 info(name='roman',city='surat')
#
# NameError: name 'info' is not defined
