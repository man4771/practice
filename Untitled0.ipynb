# %% [markdown]
# for i in "hello":
#   print(i)

# %%
for i in range(10)
  print(i)
# Out:
#   File "<ipython-input-4-12d72cac235a>", line 1
#     for i in range(10)
#                       ^
# SyntaxError: invalid syntax
