# %%
preset_acc_number = 34567543000
bank_schema = {
    67498545: {
        'pin': 4567,
        'balance': 10000.00,
        'holder_name': 'roman',
        'transactions': [{
            'amount': 100.00,
            'type': 'dr',
            'datetime': object,
        }]
    },
    67498546: {},
    67498547: {},
}
preset_acc_number = 34567543000
acc_details = {
    'acc_holder' : str(),
    'pin' : int(),
    'balance' : float(),
    'transaction' : [],
}

transaction_details = {
    'amount' : int(),
    'tr_type' : str(),
    'datetime' : object(),
}

bank = dict()
class bank_det:
  def new_acc_number(self,preset_acc_number,bank):
    self.preset_acc_number = preset_acc_number
    self.bank = bank
    print(preset_acc_number,bank)

  def introduction(self):
    return 'account number:' + self.preset_acc_number + self.bank

# %%
o = bank_det()

# %%
o.new_acc_number(preset_acc_number,bank)
# Out:
# 34567543000 {}

# %%
o.preset_acc_number
# Out:
# 34567543000

# %%
o.new_acc_number
# Out:
# <bound method bank_det.new_acc_number of <__main__.bank_det object at 0x7fc5ee2f2e90>>
