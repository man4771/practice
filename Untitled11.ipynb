# %%
class cal:
  def add(self,x,y,*z):
    s = x + y
      for i in z:
      s += i
      return s

# %%
class A:
  def method_1(self):
    print("method 1 from class A")

class B:
  def method_2(self):
    print("method 2 from class B")

# %%
o = B()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-404192b3ba0b> in <module>()
# ----> 1 o = b()
#
# NameError: name 'b' is not defined

# %%
class A:
  def method_1(self):
    print("method 1 from class A")

class B(A):
  def method_2(self):
    print("method 2 from class B")

# %%
class A:
  def method_1(self):
    print("method 1 from class A")

class B(A):
  def method_2(self):
    print("method 2 from class B")

class c(A):
  def method_3(self):
    print("method 3 from class c")

# %%
class A:
  def method_1(self):
    print("method 1 from class A")

class B():
  def method_2(self):
    print("method 2 from class B")

class c(A,B):
  def method_3(self):
    print("method 3 from class c")

# %%
o = c()

# %%
class vehical:
  def details(self):
    bus
    car
    bike
    print("bus,car,bike")

class vh(vehical):
  def details(self):
    vehical.details(self)
    name = "fff"
    print("fff")

# %%
o = vehical()

# %%
o.details
# Out:
# <bound method vehical.details of <__main__.vehical object at 0x7f55b3013690>>

# %%
o = vh()

# %%
o.details
# Out:
# <bound method vh.details of <__main__.vh object at 0x7f55b301fe10>>

# %%
class A :
  def method_1(self):
    print("method_1 from A")

class B(A) :
  def method_2(self):
    print("method_2 from A")

class C(A) :
  def method_3(self):
    print("method_3 from c")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-0e72c3f39cd8> in <module>()
#       7     print("method_2 from A")
#       8
# ----> 9 class C(A(B)) :
#      10   def method_3(self):
#      11     print("method_3 from c")
#
# TypeError: A() takes no arguments
